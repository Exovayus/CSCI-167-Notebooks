# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\danie\appdata\local\temp\pip-req-build-_vscqiic
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (3.10.7)
# Requirement already satisfied: scipy in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\danie\appdata\roaming\python\python313\site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\danie\appdata\roaming\python\python313\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\danie\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\danie\AppData\Local\Temp\pip-req-build-_vscqiic'
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# *IP
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('int64'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('int64'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.299463, train error 90.62,  test loss 2.297626, test error 90.30
# Epoch   100, train loss 1.918942, train error 73.00,  test loss 1.754257, test error 70.15
# Epoch   100, train loss 1.918942, train error 73.00,  test loss 1.754257, test error 70.15
# Epoch   200, train loss 1.916744, train error 72.28,  test loss 1.738442, test error 69.43
# Epoch   200, train loss 1.916744, train error 72.28,  test loss 1.738442, test error 69.43
# Epoch   300, train loss 1.913469, train error 72.15,  test loss 1.736216, test error 69.18
# Epoch   300, train loss 1.913469, train error 72.15,  test loss 1.736216, test error 69.18
# Epoch   400, train loss 1.920888, train error 71.85,  test loss 1.758798, test error 69.70
# Epoch   400, train loss 1.920888, train error 71.85,  test loss 1.758798, test error 69.70
# Epoch   500, train loss 1.888673, train error 70.95,  test loss 1.724654, test error 69.12
# Epoch   500, train loss 1.888673, train error 70.95,  test loss 1.724654, test error 69.12
# Epoch   600, train loss 1.885856, train error 70.10,  test loss 1.721879, test error 68.82
# Epoch   600, train loss 1.885856, train error 70.10,  test loss 1.721879, test error 68.82
# Epoch   700, train loss 1.884865, train error 71.15,  test loss 1.721494, test error 68.10
# Epoch   700, train loss 1.884865, train error 71.15,  test loss 1.721494, test error 68.10
# Epoch   800, train loss 1.885582, train error 71.32,  test loss 1.723678, test error 69.12
# Epoch   800, train loss 1.885582, train error 71.32,  test loss 1.723678, test error 69.12
# Epoch   900, train loss 1.886052, train error 70.75,  test loss 1.719744, test error 69.03
# Epoch   900, train loss 1.886052, train error 70.75,  test loss 1.719744, test error 69.03
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301544, train error 86.85,  test loss 2.301426, test error 87.18
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301544, train error 86.85,  test loss 2.301426, test error 87.18
# Epoch   100, train loss 1.728517, train error 63.00,  test loss 1.525295, test error 60.00
# Epoch   100, train loss 1.728517, train error 63.00,  test loss 1.525295, test error 60.00
# Epoch   200, train loss 1.689898, train error 61.55,  test loss 1.498184, test error 58.78
# Epoch   200, train loss 1.689898, train error 61.55,  test loss 1.498184, test error 58.78
# Epoch   300, train loss 1.680008, train error 60.35,  test loss 1.492351, test error 57.05
# Epoch   300, train loss 1.680008, train error 60.35,  test loss 1.492351, test error 57.05
# Epoch   400, train loss 1.672853, train error 60.92,  test loss 1.470383, test error 57.80
# Epoch   400, train loss 1.672853, train error 60.92,  test loss 1.470383, test error 57.80
# Epoch   500, train loss 1.674127, train error 60.85,  test loss 1.480289, test error 56.88
# Epoch   500, train loss 1.674127, train error 60.85,  test loss 1.480289, test error 56.88
# Epoch   600, train loss 1.678836, train error 61.92,  test loss 1.488684, test error 58.85
# Epoch   600, train loss 1.678836, train error 61.92,  test loss 1.488684, test error 58.85
# Epoch   700, train loss 1.663677, train error 60.45,  test loss 1.476366, test error 56.60
# Epoch   700, train loss 1.663677, train error 60.45,  test loss 1.476366, test error 56.60
# Epoch   800, train loss 1.663899, train error 61.30,  test loss 1.478535, test error 57.83
# Epoch   800, train loss 1.663899, train error 61.30,  test loss 1.478535, test error 57.83
# Epoch   900, train loss 1.669483, train error 61.08,  test loss 1.492442, test error 57.65
# Epoch   900, train loss 1.669483, train error 61.08,  test loss 1.492442, test error 57.65
# Training model with   6 hidden variables
# Epoch     0, train loss 2.228943, train error 88.95,  test loss 2.224577, test error 88.50
# Training model with   6 hidden variables
# Epoch     0, train loss 2.228943, train error 88.95,  test loss 2.224577, test error 88.50
# Epoch   100, train loss 1.657408, train error 58.53,  test loss 1.468287, test error 55.33
# Epoch   100, train loss 1.657408, train error 58.53,  test loss 1.468287, test error 55.33
# Epoch   200, train loss 1.623585, train error 56.58,  test loss 1.435305, test error 54.60
# Epoch   200, train loss 1.623585, train error 56.58,  test loss 1.435305, test error 54.60
# Epoch   300, train loss 1.619429, train error 55.97,  test loss 1.433280, test error 54.40
# Epoch   300, train loss 1.619429, train error 55.97,  test loss 1.433280, test error 54.40
# Epoch   400, train loss 1.605432, train error 56.33,  test loss 1.424918, test error 54.40
# Epoch   400, train loss 1.605432, train error 56.33,  test loss 1.424918, test error 54.40
# Epoch   500, train loss 1.591624, train error 56.25,  test loss 1.415830, test error 53.60
# Epoch   500, train loss 1.591624, train error 56.25,  test loss 1.415830, test error 53.60
# Epoch   600, train loss 1.584188, train error 56.35,  test loss 1.423288, test error 54.08
# Epoch   600, train loss 1.584188, train error 56.35,  test loss 1.423288, test error 54.08
# Epoch   700, train loss 1.584920, train error 56.45,  test loss 1.427645, test error 53.42
# Epoch   700, train loss 1.584920, train error 56.45,  test loss 1.427645, test error 53.42
# Epoch   800, train loss 1.581885, train error 56.20,  test loss 1.421777, test error 53.08
# Epoch   800, train loss 1.581885, train error 56.20,  test loss 1.421777, test error 53.08
# Epoch   900, train loss 1.578844, train error 56.12,  test loss 1.420262, test error 53.28
# Epoch   900, train loss 1.578844, train error 56.12,  test loss 1.420262, test error 53.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.231096, train error 83.40,  test loss 2.223059, test error 83.62
# Training model with   8 hidden variables
# Epoch     0, train loss 2.231096, train error 83.40,  test loss 2.223059, test error 83.62
# Epoch   100, train loss 1.648075, train error 60.38,  test loss 1.491686, test error 56.67
# Epoch   100, train loss 1.648075, train error 60.38,  test loss 1.491686, test error 56.67
# Epoch   200, train loss 1.587272, train error 57.15,  test loss 1.433998, test error 54.35
# Epoch   200, train loss 1.587272, train error 57.15,  test loss 1.433998, test error 54.35
# Epoch   300, train loss 1.573605, train error 55.80,  test loss 1.425213, test error 54.45
# Epoch   300, train loss 1.573605, train error 55.80,  test loss 1.425213, test error 54.45
# Epoch   400, train loss 1.565674, train error 55.78,  test loss 1.433167, test error 54.42
# Epoch   400, train loss 1.565674, train error 55.78,  test loss 1.433167, test error 54.42
# Epoch   500, train loss 1.557625, train error 55.67,  test loss 1.438364, test error 54.62
# Epoch   500, train loss 1.557625, train error 55.67,  test loss 1.438364, test error 54.62
# Epoch   600, train loss 1.550452, train error 55.12,  test loss 1.452643, test error 55.20
# Epoch   600, train loss 1.550452, train error 55.12,  test loss 1.452643, test error 55.20
# Epoch   700, train loss 1.549568, train error 55.42,  test loss 1.452910, test error 55.00
# Epoch   700, train loss 1.549568, train error 55.42,  test loss 1.452910, test error 55.00
# Epoch   800, train loss 1.545405, train error 54.53,  test loss 1.455728, test error 54.58
# Epoch   800, train loss 1.545405, train error 54.53,  test loss 1.455728, test error 54.58
# Epoch   900, train loss 1.541231, train error 53.90,  test loss 1.448284, test error 54.45
# Epoch   900, train loss 1.541231, train error 53.90,  test loss 1.448284, test error 54.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.163202, train error 79.35,  test loss 2.117105, test error 78.40
# Training model with  10 hidden variables
# Epoch     0, train loss 2.163202, train error 79.35,  test loss 2.117105, test error 78.40
# Epoch   100, train loss 1.488461, train error 50.10,  test loss 1.302328, test error 48.92
# Epoch   100, train loss 1.488461, train error 50.10,  test loss 1.302328, test error 48.92
# Epoch   200, train loss 1.419528, train error 47.90,  test loss 1.246703, test error 46.28
# Epoch   200, train loss 1.419528, train error 47.90,  test loss 1.246703, test error 46.28
# Epoch   300, train loss 1.403772, train error 47.12,  test loss 1.255257, test error 46.33
# Epoch   300, train loss 1.403772, train error 47.12,  test loss 1.255257, test error 46.33
# Epoch   400, train loss 1.392804, train error 46.70,  test loss 1.250358, test error 45.88
# Epoch   400, train loss 1.392804, train error 46.70,  test loss 1.250358, test error 45.88
# Epoch   500, train loss 1.383004, train error 45.83,  test loss 1.260583, test error 45.83
# Epoch   500, train loss 1.383004, train error 45.83,  test loss 1.260583, test error 45.83
# Epoch   600, train loss 1.365429, train error 46.05,  test loss 1.265113, test error 46.62
# Epoch   600, train loss 1.365429, train error 46.05,  test loss 1.265113, test error 46.62
# Epoch   700, train loss 1.359096, train error 45.62,  test loss 1.270410, test error 46.72
# Epoch   700, train loss 1.359096, train error 45.62,  test loss 1.270410, test error 46.72
# Epoch   800, train loss 1.358515, train error 45.33,  test loss 1.276657, test error 47.05
# Epoch   800, train loss 1.358515, train error 45.33,  test loss 1.276657, test error 47.05
# Epoch   900, train loss 1.354852, train error 46.00,  test loss 1.270366, test error 47.35
# Epoch   900, train loss 1.354852, train error 46.00,  test loss 1.270366, test error 47.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.144322, train error 80.78,  test loss 2.104158, test error 79.80
# Training model with  14 hidden variables
# Epoch     0, train loss 2.144322, train error 80.78,  test loss 2.104158, test error 79.80
# Epoch   100, train loss 1.477685, train error 51.22,  test loss 1.429359, test error 53.85
# Epoch   100, train loss 1.477685, train error 51.22,  test loss 1.429359, test error 53.85
# Epoch   200, train loss 1.379363, train error 47.03,  test loss 1.376283, test error 51.33
# Epoch   200, train loss 1.379363, train error 47.03,  test loss 1.376283, test error 51.33
# Epoch   300, train loss 1.335094, train error 45.45,  test loss 1.374334, test error 50.40
# Epoch   300, train loss 1.335094, train error 45.45,  test loss 1.374334, test error 50.40
# Epoch   400, train loss 1.312334, train error 43.78,  test loss 1.396743, test error 50.62
# Epoch   400, train loss 1.312334, train error 43.78,  test loss 1.396743, test error 50.62
# Epoch   500, train loss 1.310505, train error 43.83,  test loss 1.420140, test error 50.33
# Epoch   500, train loss 1.310505, train error 43.83,  test loss 1.420140, test error 50.33
# Epoch   600, train loss 1.296121, train error 44.12,  test loss 1.441071, test error 50.58
# Epoch   600, train loss 1.296121, train error 44.12,  test loss 1.441071, test error 50.58
# Epoch   700, train loss 1.291270, train error 43.97,  test loss 1.442720, test error 50.50
# Epoch   700, train loss 1.291270, train error 43.97,  test loss 1.442720, test error 50.50
# Epoch   800, train loss 1.280418, train error 43.58,  test loss 1.456340, test error 50.85
# Epoch   800, train loss 1.280418, train error 43.58,  test loss 1.456340, test error 50.85
# Epoch   900, train loss 1.276242, train error 43.20,  test loss 1.496310, test error 50.35
# Epoch   900, train loss 1.276242, train error 43.20,  test loss 1.496310, test error 50.35
# Training model with  18 hidden variables
# Epoch     0, train loss 2.206554, train error 82.20,  test loss 2.177407, test error 80.97
# Training model with  18 hidden variables
# Epoch     0, train loss 2.206554, train error 82.20,  test loss 2.177407, test error 80.97
# Epoch   100, train loss 1.345140, train error 44.55,  test loss 1.291001, test error 47.17
# Epoch   100, train loss 1.345140, train error 44.55,  test loss 1.291001, test error 47.17
# Epoch   200, train loss 1.250041, train error 41.60,  test loss 1.311698, test error 49.05
# Epoch   200, train loss 1.250041, train error 41.60,  test loss 1.311698, test error 49.05
# Epoch   300, train loss 1.206097, train error 41.08,  test loss 1.348000, test error 48.75
# Epoch   300, train loss 1.206097, train error 41.08,  test loss 1.348000, test error 48.75
# Epoch   400, train loss 1.173173, train error 39.92,  test loss 1.402197, test error 49.88
# Epoch   400, train loss 1.173173, train error 39.92,  test loss 1.402197, test error 49.88
# Epoch   500, train loss 1.152170, train error 39.08,  test loss 1.438095, test error 50.38
# Epoch   500, train loss 1.152170, train error 39.08,  test loss 1.438095, test error 50.38
# Epoch   600, train loss 1.137397, train error 38.90,  test loss 1.478847, test error 50.80
# Epoch   600, train loss 1.137397, train error 38.90,  test loss 1.478847, test error 50.80
# Epoch   700, train loss 1.142369, train error 38.78,  test loss 1.515561, test error 50.97
# Epoch   700, train loss 1.142369, train error 38.78,  test loss 1.515561, test error 50.97
# Epoch   800, train loss 1.123472, train error 39.05,  test loss 1.542705, test error 50.88
# Epoch   800, train loss 1.123472, train error 39.05,  test loss 1.542705, test error 50.88
# Epoch   900, train loss 1.116273, train error 38.33,  test loss 1.564738, test error 51.20
# Epoch   900, train loss 1.116273, train error 38.33,  test loss 1.564738, test error 51.20
# Training model with  22 hidden variables
# Epoch     0, train loss 2.173079, train error 81.43,  test loss 2.128914, test error 79.47
# Training model with  22 hidden variables
# Epoch     0, train loss 2.173079, train error 81.43,  test loss 2.128914, test error 79.47
# Epoch   100, train loss 1.292091, train error 43.12,  test loss 1.321050, test error 49.20
# Epoch   100, train loss 1.292091, train error 43.12,  test loss 1.321050, test error 49.20
# Epoch   200, train loss 1.159247, train error 39.10,  test loss 1.380375, test error 49.00
# Epoch   200, train loss 1.159247, train error 39.10,  test loss 1.380375, test error 49.00
# Epoch   300, train loss 1.103065, train error 37.90,  test loss 1.450528, test error 49.92
# Epoch   300, train loss 1.103065, train error 37.90,  test loss 1.450528, test error 49.92
# Epoch   400, train loss 1.072690, train error 37.17,  test loss 1.506269, test error 49.70
# Epoch   400, train loss 1.072690, train error 37.17,  test loss 1.506269, test error 49.70
# Epoch   500, train loss 1.043603, train error 36.72,  test loss 1.563247, test error 51.45
# Epoch   500, train loss 1.043603, train error 36.72,  test loss 1.563247, test error 51.45
# Epoch   600, train loss 1.016421, train error 36.40,  test loss 1.640416, test error 52.03
# Epoch   600, train loss 1.016421, train error 36.40,  test loss 1.640416, test error 52.03
# Epoch   700, train loss 1.013083, train error 36.90,  test loss 1.718025, test error 52.60
# Epoch   700, train loss 1.013083, train error 36.90,  test loss 1.718025, test error 52.60
# Epoch   800, train loss 0.984675, train error 35.25,  test loss 1.738693, test error 53.17
# Epoch   800, train loss 0.984675, train error 35.25,  test loss 1.738693, test error 53.17
# Epoch   900, train loss 0.979026, train error 34.97,  test loss 1.804469, test error 54.08
# Epoch   900, train loss 0.979026, train error 34.97,  test loss 1.804469, test error 54.08
# Training model with  26 hidden variables
# Epoch     0, train loss 2.219650, train error 81.47,  test loss 2.206072, test error 82.45
# Training model with  26 hidden variables
# Epoch     0, train loss 2.219650, train error 81.47,  test loss 2.206072, test error 82.45
# Epoch   100, train loss 1.192547, train error 38.05,  test loss 1.293768, test error 46.58
# Epoch   100, train loss 1.192547, train error 38.05,  test loss 1.293768, test error 46.58
# Epoch   200, train loss 1.044202, train error 34.45,  test loss 1.401473, test error 48.72
# Epoch   200, train loss 1.044202, train error 34.45,  test loss 1.401473, test error 48.72
# Epoch   300, train loss 0.979835, train error 32.72,  test loss 1.532893, test error 49.53
# Epoch   300, train loss 0.979835, train error 32.72,  test loss 1.532893, test error 49.53
# Epoch   400, train loss 0.926153, train error 30.97,  test loss 1.629161, test error 51.42
# Epoch   400, train loss 0.926153, train error 30.97,  test loss 1.629161, test error 51.42
# Epoch   500, train loss 0.901169, train error 31.03,  test loss 1.723563, test error 52.25
# Epoch   500, train loss 0.901169, train error 31.03,  test loss 1.723563, test error 52.25
# Epoch   600, train loss 0.871288, train error 29.45,  test loss 1.766271, test error 52.08
# Epoch   600, train loss 0.871288, train error 29.45,  test loss 1.766271, test error 52.08
# Epoch   700, train loss 0.859981, train error 29.62,  test loss 1.869022, test error 52.97
# Epoch   700, train loss 0.859981, train error 29.62,  test loss 1.869022, test error 52.97
# Epoch   800, train loss 0.848484, train error 29.30,  test loss 1.936770, test error 52.92
# Epoch   800, train loss 0.848484, train error 29.30,  test loss 1.936770, test error 52.92
# Epoch   900, train loss 0.820482, train error 27.88,  test loss 2.006258, test error 52.53
# Epoch   900, train loss 0.820482, train error 27.88,  test loss 2.006258, test error 52.53
# Training model with  30 hidden variables
# Epoch     0, train loss 2.106268, train error 79.40,  test loss 2.048037, test error 77.35
# Training model with  30 hidden variables
# Epoch     0, train loss 2.106268, train error 79.40,  test loss 2.048037, test error 77.35
# Epoch   100, train loss 1.127072, train error 36.45,  test loss 1.332141, test error 48.45
# Epoch   100, train loss 1.127072, train error 36.45,  test loss 1.332141, test error 48.45
# Epoch   200, train loss 0.943636, train error 31.32,  test loss 1.529361, test error 50.15
# Epoch   200, train loss 0.943636, train error 31.32,  test loss 1.529361, test error 50.15
# Epoch   300, train loss 0.830886, train error 27.75,  test loss 1.740158, test error 51.88
# Epoch   300, train loss 0.830886, train error 27.75,  test loss 1.740158, test error 51.88
# Epoch   400, train loss 0.772751, train error 25.68,  test loss 1.926238, test error 53.00
# Epoch   400, train loss 0.772751, train error 25.68,  test loss 1.926238, test error 53.00
# Epoch   500, train loss 0.757256, train error 25.40,  test loss 2.101492, test error 53.08
# Epoch   500, train loss 0.757256, train error 25.40,  test loss 2.101492, test error 53.08
# Epoch   600, train loss 0.715692, train error 23.88,  test loss 2.240086, test error 53.97
# Epoch   600, train loss 0.715692, train error 23.88,  test loss 2.240086, test error 53.97
# Epoch   700, train loss 0.701726, train error 24.18,  test loss 2.423898, test error 55.05
# Epoch   700, train loss 0.701726, train error 24.18,  test loss 2.423898, test error 55.05
# Epoch   800, train loss 0.677028, train error 23.22,  test loss 2.561562, test error 55.12
# Epoch   800, train loss 0.677028, train error 23.22,  test loss 2.561562, test error 55.12
# Epoch   900, train loss 0.668429, train error 22.75,  test loss 2.685473, test error 55.20
# Epoch   900, train loss 0.668429, train error 22.75,  test loss 2.685473, test error 55.20
# Training model with  35 hidden variables
# Epoch     0, train loss 2.109070, train error 77.25,  test loss 2.056415, test error 77.93
# Training model with  35 hidden variables
# Epoch     0, train loss 2.109070, train error 77.25,  test loss 2.056415, test error 77.93
# Epoch   100, train loss 1.028176, train error 33.35,  test loss 1.421560, test error 50.17
# Epoch   100, train loss 1.028176, train error 33.35,  test loss 1.421560, test error 50.17
# Epoch   200, train loss 0.807544, train error 27.20,  test loss 1.740552, test error 52.75
# Epoch   200, train loss 0.807544, train error 27.20,  test loss 1.740552, test error 52.75
# Epoch   300, train loss 0.698377, train error 23.90,  test loss 2.074053, test error 55.25
# Epoch   300, train loss 0.698377, train error 23.90,  test loss 2.074053, test error 55.25
# Epoch   400, train loss 0.622691, train error 21.30,  test loss 2.406893, test error 56.28
# Epoch   400, train loss 0.622691, train error 21.30,  test loss 2.406893, test error 56.28
# Epoch   500, train loss 0.589239, train error 19.95,  test loss 2.737610, test error 57.00
# Epoch   500, train loss 0.589239, train error 19.95,  test loss 2.737610, test error 57.00
# Epoch   600, train loss 0.534374, train error 17.62,  test loss 3.036449, test error 56.97
# Epoch   600, train loss 0.534374, train error 17.62,  test loss 3.036449, test error 56.97
# Epoch   700, train loss 0.530747, train error 18.38,  test loss 3.320682, test error 57.33
# Epoch   700, train loss 0.530747, train error 18.38,  test loss 3.320682, test error 57.33
# Epoch   800, train loss 0.487637, train error 16.60,  test loss 3.556378, test error 57.40
# Epoch   800, train loss 0.487637, train error 16.60,  test loss 3.556378, test error 57.40
# Epoch   900, train loss 0.477016, train error 16.62,  test loss 3.786783, test error 57.88
# Epoch   900, train loss 0.477016, train error 16.62,  test loss 3.786783, test error 57.88
# Training model with  40 hidden variables
# Epoch     0, train loss 2.107881, train error 77.93,  test loss 2.074914, test error 78.43
# Training model with  40 hidden variables
# Epoch     0, train loss 2.107881, train error 77.93,  test loss 2.074914, test error 78.43
# Epoch   100, train loss 0.928801, train error 30.43,  test loss 1.433251, test error 50.20
# Epoch   100, train loss 0.928801, train error 30.43,  test loss 1.433251, test error 50.20
# Epoch   200, train loss 0.656402, train error 20.97,  test loss 1.949485, test error 52.53
# Epoch   200, train loss 0.656402, train error 20.97,  test loss 1.949485, test error 52.53
# Epoch   300, train loss 0.548278, train error 19.53,  test loss 2.698855, test error 54.60
# Epoch   300, train loss 0.548278, train error 19.53,  test loss 2.698855, test error 54.60
# Epoch   400, train loss 0.419723, train error 13.62,  test loss 3.349785, test error 54.58
# Epoch   400, train loss 0.419723, train error 13.62,  test loss 3.349785, test error 54.58
# Epoch   500, train loss 0.300949, train error 9.40,  test loss 4.098708, test error 55.53
# Epoch   500, train loss 0.300949, train error 9.40,  test loss 4.098708, test error 55.53
# Epoch   600, train loss 0.285177, train error 9.55,  test loss 4.888407, test error 56.05
# Epoch   600, train loss 0.285177, train error 9.55,  test loss 4.888407, test error 56.05
# Epoch   700, train loss 0.313355, train error 10.72,  test loss 5.588415, test error 56.92
# Epoch   700, train loss 0.313355, train error 10.72,  test loss 5.588415, test error 56.92
# Epoch   800, train loss 0.287735, train error 10.28,  test loss 6.092558, test error 56.88
# Epoch   800, train loss 0.287735, train error 10.28,  test loss 6.092558, test error 56.88
# Epoch   900, train loss 0.214500, train error 7.55,  test loss 6.745893, test error 57.03
# Epoch   900, train loss 0.214500, train error 7.55,  test loss 6.745893, test error 57.03
# Training model with  45 hidden variables
# Epoch     0, train loss 2.136219, train error 78.47,  test loss 2.118200, test error 78.45
# Training model with  45 hidden variables
# Epoch     0, train loss 2.136219, train error 78.47,  test loss 2.118200, test error 78.45
# Epoch   100, train loss 0.789438, train error 24.68,  test loss 1.462173, test error 48.38
# Epoch   100, train loss 0.789438, train error 24.68,  test loss 1.462173, test error 48.38
# Epoch   200, train loss 0.461737, train error 14.15,  test loss 2.259154, test error 51.45
# Epoch   200, train loss 0.461737, train error 14.15,  test loss 2.259154, test error 51.45
# Epoch   300, train loss 0.316922, train error 10.30,  test loss 3.391271, test error 54.08
# Epoch   300, train loss 0.316922, train error 10.30,  test loss 3.391271, test error 54.08
# Epoch   400, train loss 0.230078, train error 7.75,  test loss 4.493597, test error 54.22
# Epoch   400, train loss 0.230078, train error 7.75,  test loss 4.493597, test error 54.22
# Epoch   500, train loss 0.188984, train error 5.80,  test loss 5.840337, test error 55.10
# Epoch   500, train loss 0.188984, train error 5.80,  test loss 5.840337, test error 55.10
# Epoch   600, train loss 0.092756, train error 2.72,  test loss 7.063495, test error 55.12
# Epoch   600, train loss 0.092756, train error 2.72,  test loss 7.063495, test error 55.12
# Epoch   700, train loss 0.012384, train error 0.00,  test loss 7.983554, test error 54.53
# Epoch   700, train loss 0.012384, train error 0.00,  test loss 7.983554, test error 54.53
# Epoch   800, train loss 0.007309, train error 0.00,  test loss 8.648145, test error 54.90
# Epoch   800, train loss 0.007309, train error 0.00,  test loss 8.648145, test error 54.90
# Epoch   900, train loss 0.005539, train error 0.00,  test loss 9.110834, test error 54.88
# Epoch   900, train loss 0.005539, train error 0.00,  test loss 9.110834, test error 54.88
# Training model with  50 hidden variables
# Epoch     0, train loss 2.050460, train error 75.32,  test loss 1.985381, test error 75.57
# Training model with  50 hidden variables
# Epoch     0, train loss 2.050460, train error 75.32,  test loss 1.985381, test error 75.57
# Epoch   100, train loss 0.734429, train error 22.57,  test loss 1.563976, test error 50.03
# Epoch   100, train loss 0.734429, train error 22.57,  test loss 1.563976, test error 50.03
# Epoch   200, train loss 0.388214, train error 11.97,  test loss 2.692533, test error 54.50
# Epoch   200, train loss 0.388214, train error 11.97,  test loss 2.692533, test error 54.50
# Epoch   300, train loss 0.179173, train error 4.88,  test loss 4.284347, test error 55.95
# Epoch   300, train loss 0.179173, train error 4.88,  test loss 4.284347, test error 55.95
# Epoch   400, train loss 0.055319, train error 0.40,  test loss 5.937363, test error 56.67
# Epoch   400, train loss 0.055319, train error 0.40,  test loss 5.937363, test error 56.67
# Epoch   500, train loss 0.013022, train error 0.00,  test loss 6.987974, test error 56.80
# Epoch   500, train loss 0.013022, train error 0.00,  test loss 6.987974, test error 56.80
# Epoch   600, train loss 0.008327, train error 0.00,  test loss 7.662280, test error 57.12
# Epoch   600, train loss 0.008327, train error 0.00,  test loss 7.662280, test error 57.12
# Epoch   700, train loss 0.005891, train error 0.00,  test loss 8.143543, test error 56.90
# Epoch   700, train loss 0.005891, train error 0.00,  test loss 8.143543, test error 56.90
# Epoch   800, train loss 0.004561, train error 0.00,  test loss 8.535707, test error 57.05
# Epoch   800, train loss 0.004561, train error 0.00,  test loss 8.535707, test error 57.05
# Epoch   900, train loss 0.003700, train error 0.00,  test loss 8.859942, test error 57.00
# Epoch   900, train loss 0.003700, train error 0.00,  test loss 8.859942, test error 57.00
# Training model with  55 hidden variables
# Epoch     0, train loss 2.074480, train error 77.65,  test loss 2.015332, test error 77.62
# Training model with  55 hidden variables
# Epoch     0, train loss 2.074480, train error 77.65,  test loss 2.015332, test error 77.62
# Epoch   100, train loss 0.604467, train error 18.32,  test loss 1.763642, test error 52.22
# Epoch   100, train loss 0.604467, train error 18.32,  test loss 1.763642, test error 52.22
# Epoch   200, train loss 0.201024, train error 4.50,  test loss 3.220360, test error 55.20
# Epoch   200, train loss 0.201024, train error 4.50,  test loss 3.220360, test error 55.20
# Epoch   300, train loss 0.036474, train error 0.05,  test loss 4.941162, test error 56.25
# Epoch   300, train loss 0.036474, train error 0.05,  test loss 4.941162, test error 56.25
# Epoch   400, train loss 0.013974, train error 0.00,  test loss 5.982413, test error 56.40
# Epoch   400, train loss 0.013974, train error 0.00,  test loss 5.982413, test error 56.40
# Epoch   500, train loss 0.008288, train error 0.00,  test loss 6.607190, test error 56.03
# Epoch   500, train loss 0.008288, train error 0.00,  test loss 6.607190, test error 56.03
# Epoch   600, train loss 0.005662, train error 0.00,  test loss 7.059215, test error 56.35
# Epoch   600, train loss 0.005662, train error 0.00,  test loss 7.059215, test error 56.35
# Epoch   700, train loss 0.004274, train error 0.00,  test loss 7.406975, test error 56.35
# Epoch   700, train loss 0.004274, train error 0.00,  test loss 7.406975, test error 56.35
# Epoch   800, train loss 0.003383, train error 0.00,  test loss 7.705684, test error 56.28
# Epoch   800, train loss 0.003383, train error 0.00,  test loss 7.705684, test error 56.28
# Epoch   900, train loss 0.002772, train error 0.00,  test loss 7.943130, test error 56.38
# Epoch   900, train loss 0.002772, train error 0.00,  test loss 7.943130, test error 56.38
# Training model with  60 hidden variables
# Epoch     0, train loss 2.054852, train error 76.97,  test loss 2.001200, test error 75.65
# Training model with  60 hidden variables
# Epoch     0, train loss 2.054852, train error 76.97,  test loss 2.001200, test error 75.65
# Epoch   100, train loss 0.496108, train error 13.82,  test loss 1.845442, test error 52.17
# Epoch   100, train loss 0.496108, train error 13.82,  test loss 1.845442, test error 52.17
# Epoch   200, train loss 0.091272, train error 0.68,  test loss 3.558614, test error 55.22
# Epoch   200, train loss 0.091272, train error 0.68,  test loss 3.558614, test error 55.22
# Epoch   300, train loss 0.019092, train error 0.00,  test loss 4.887621, test error 56.03
# Epoch   300, train loss 0.019092, train error 0.00,  test loss 4.887621, test error 56.03
# Epoch   400, train loss 0.009254, train error 0.00,  test loss 5.577868, test error 56.53
# Epoch   400, train loss 0.009254, train error 0.00,  test loss 5.577868, test error 56.53
# Epoch   500, train loss 0.005854, train error 0.00,  test loss 6.036542, test error 56.50
# Epoch   500, train loss 0.005854, train error 0.00,  test loss 6.036542, test error 56.50
# Epoch   600, train loss 0.004188, train error 0.00,  test loss 6.379057, test error 56.55
# Epoch   600, train loss 0.004188, train error 0.00,  test loss 6.379057, test error 56.55
# Epoch   700, train loss 0.003225, train error 0.00,  test loss 6.651224, test error 56.75
# Epoch   700, train loss 0.003225, train error 0.00,  test loss 6.651224, test error 56.75
# Epoch   800, train loss 0.002595, train error 0.00,  test loss 6.875991, test error 56.88
# Epoch   800, train loss 0.002595, train error 0.00,  test loss 6.875991, test error 56.88
# Epoch   900, train loss 0.002150, train error 0.00,  test loss 7.070829, test error 56.78
# Epoch   900, train loss 0.002150, train error 0.00,  test loss 7.070829, test error 56.78
# Training model with  70 hidden variables
# Epoch     0, train loss 2.042313, train error 75.95,  test loss 1.987558, test error 77.03
# Training model with  70 hidden variables
# Epoch     0, train loss 2.042313, train error 75.95,  test loss 1.987558, test error 77.03
# Epoch   100, train loss 0.349775, train error 8.12,  test loss 1.916781, test error 50.50
# Epoch   100, train loss 0.349775, train error 8.12,  test loss 1.916781, test error 50.50
# Epoch   200, train loss 0.033482, train error 0.00,  test loss 3.606867, test error 53.45
# Epoch   200, train loss 0.033482, train error 0.00,  test loss 3.606867, test error 53.45
# Epoch   300, train loss 0.010858, train error 0.00,  test loss 4.382233, test error 53.50
# Epoch   300, train loss 0.010858, train error 0.00,  test loss 4.382233, test error 53.50
# Epoch   400, train loss 0.006102, train error 0.00,  test loss 4.825171, test error 53.83
# Epoch   400, train loss 0.006102, train error 0.00,  test loss 4.825171, test error 53.83
# Epoch   500, train loss 0.004101, train error 0.00,  test loss 5.125959, test error 53.95
# Epoch   500, train loss 0.004101, train error 0.00,  test loss 5.125959, test error 53.95
# Epoch   600, train loss 0.003036, train error 0.00,  test loss 5.358067, test error 54.00
# Epoch   600, train loss 0.003036, train error 0.00,  test loss 5.358067, test error 54.00
# Epoch   700, train loss 0.002383, train error 0.00,  test loss 5.543251, test error 54.15
# Epoch   700, train loss 0.002383, train error 0.00,  test loss 5.543251, test error 54.15
# Epoch   800, train loss 0.001948, train error 0.00,  test loss 5.701333, test error 54.15
# Epoch   800, train loss 0.001948, train error 0.00,  test loss 5.701333, test error 54.15
# Epoch   900, train loss 0.001639, train error 0.00,  test loss 5.835687, test error 54.10
# Epoch   900, train loss 0.001639, train error 0.00,  test loss 5.835687, test error 54.10
# Training model with  80 hidden variables
# Epoch     0, train loss 2.043404, train error 75.90,  test loss 1.978496, test error 75.22
# Training model with  80 hidden variables
# Epoch     0, train loss 2.043404, train error 75.90,  test loss 1.978496, test error 75.22
# Epoch   100, train loss 0.234748, train error 4.60,  test loss 2.024099, test error 50.55
# Epoch   100, train loss 0.234748, train error 4.60,  test loss 2.024099, test error 50.55
# Epoch   200, train loss 0.018950, train error 0.00,  test loss 3.205649, test error 51.03
# Epoch   200, train loss 0.018950, train error 0.00,  test loss 3.205649, test error 51.03
# Epoch   300, train loss 0.007704, train error 0.00,  test loss 3.716481, test error 51.67
# Epoch   300, train loss 0.007704, train error 0.00,  test loss 3.716481, test error 51.67
# Epoch   400, train loss 0.004587, train error 0.00,  test loss 4.016680, test error 51.85
# Epoch   400, train loss 0.004587, train error 0.00,  test loss 4.016680, test error 51.85
# Epoch   500, train loss 0.003173, train error 0.00,  test loss 4.238511, test error 51.88
# Epoch   500, train loss 0.003173, train error 0.00,  test loss 4.238511, test error 51.88
# Epoch   600, train loss 0.002395, train error 0.00,  test loss 4.403661, test error 51.67
# Epoch   600, train loss 0.002395, train error 0.00,  test loss 4.403661, test error 51.67
# Epoch   700, train loss 0.001903, train error 0.00,  test loss 4.542046, test error 51.80
# Epoch   700, train loss 0.001903, train error 0.00,  test loss 4.542046, test error 51.80
# Epoch   800, train loss 0.001568, train error 0.00,  test loss 4.658264, test error 51.83
# Epoch   800, train loss 0.001568, train error 0.00,  test loss 4.658264, test error 51.83
# Epoch   900, train loss 0.001326, train error 0.00,  test loss 4.759612, test error 51.72
# Epoch   900, train loss 0.001326, train error 0.00,  test loss 4.759612, test error 51.72
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020847, train error 74.72,  test loss 1.939130, test error 73.20
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020847, train error 74.72,  test loss 1.939130, test error 73.20
# Epoch   100, train loss 0.133054, train error 0.93,  test loss 2.190023, test error 50.92
# Epoch   100, train loss 0.133054, train error 0.93,  test loss 2.190023, test error 50.92
# Epoch   200, train loss 0.014545, train error 0.00,  test loss 3.187587, test error 50.70
# Epoch   200, train loss 0.014545, train error 0.00,  test loss 3.187587, test error 50.70
# Epoch   300, train loss 0.006442, train error 0.00,  test loss 3.608845, test error 51.00
# Epoch   300, train loss 0.006442, train error 0.00,  test loss 3.608845, test error 51.00
# Epoch   400, train loss 0.003952, train error 0.00,  test loss 3.867344, test error 50.88
# Epoch   400, train loss 0.003952, train error 0.00,  test loss 3.867344, test error 50.88
# Epoch   500, train loss 0.002783, train error 0.00,  test loss 4.047905, test error 50.85
# Epoch   500, train loss 0.002783, train error 0.00,  test loss 4.047905, test error 50.85
# Epoch   600, train loss 0.002119, train error 0.00,  test loss 4.194487, test error 51.03
# Epoch   600, train loss 0.002119, train error 0.00,  test loss 4.194487, test error 51.03
# Epoch   700, train loss 0.001693, train error 0.00,  test loss 4.312049, test error 50.83
# Epoch   700, train loss 0.001693, train error 0.00,  test loss 4.312049, test error 50.83
# Epoch   800, train loss 0.001401, train error 0.00,  test loss 4.412220, test error 50.90
# Epoch   800, train loss 0.001401, train error 0.00,  test loss 4.412220, test error 50.90
# Epoch   900, train loss 0.001190, train error 0.00,  test loss 4.500753, test error 50.88
# Epoch   900, train loss 0.001190, train error 0.00,  test loss 4.500753, test error 50.88
# Training model with 100 hidden variables
# Epoch     0, train loss 1.968711, train error 72.62,  test loss 1.931268, test error 74.20
# Training model with 100 hidden variables
# Epoch     0, train loss 1.968711, train error 72.62,  test loss 1.931268, test error 74.20
# Epoch   100, train loss 0.082916, train error 0.05,  test loss 2.291799, test error 51.25
# Epoch   100, train loss 0.082916, train error 0.05,  test loss 2.291799, test error 51.25
# Epoch   200, train loss 0.011427, train error 0.00,  test loss 3.120529, test error 50.80
# Epoch   200, train loss 0.011427, train error 0.00,  test loss 3.120529, test error 50.80
# Epoch   300, train loss 0.005389, train error 0.00,  test loss 3.470024, test error 50.95
# Epoch   300, train loss 0.005389, train error 0.00,  test loss 3.470024, test error 50.95
# Epoch   400, train loss 0.003374, train error 0.00,  test loss 3.690047, test error 51.10
# Epoch   400, train loss 0.003374, train error 0.00,  test loss 3.690047, test error 51.10
# Epoch   500, train loss 0.002403, train error 0.00,  test loss 3.848249, test error 50.92
# Epoch   500, train loss 0.002403, train error 0.00,  test loss 3.848249, test error 50.92
# Epoch   600, train loss 0.001846, train error 0.00,  test loss 3.974779, test error 50.90
# Epoch   600, train loss 0.001846, train error 0.00,  test loss 3.974779, test error 50.90
# Epoch   700, train loss 0.001484, train error 0.00,  test loss 4.076516, test error 50.95
# Epoch   700, train loss 0.001484, train error 0.00,  test loss 4.076516, test error 50.95
# Epoch   800, train loss 0.001235, train error 0.00,  test loss 4.163165, test error 50.85
# Epoch   800, train loss 0.001235, train error 0.00,  test loss 4.163165, test error 50.85
# Epoch   900, train loss 0.001052, train error 0.00,  test loss 4.238377, test error 50.80
# Epoch   900, train loss 0.001052, train error 0.00,  test loss 4.238377, test error 50.80
# Training model with 120 hidden variables
# Epoch     0, train loss 1.961865, train error 72.65,  test loss 1.904776, test error 73.45
# Training model with 120 hidden variables
# Epoch     0, train loss 1.961865, train error 72.65,  test loss 1.904776, test error 73.45
# Epoch   100, train loss 0.051766, train error 0.00,  test loss 2.254844, test error 50.80
# Epoch   100, train loss 0.051766, train error 0.00,  test loss 2.254844, test error 50.80
# Epoch   200, train loss 0.009623, train error 0.00,  test loss 2.866865, test error 50.60
# Epoch   200, train loss 0.009623, train error 0.00,  test loss 2.866865, test error 50.60
# Epoch   300, train loss 0.004727, train error 0.00,  test loss 3.154824, test error 50.80
# Epoch   300, train loss 0.004727, train error 0.00,  test loss 3.154824, test error 50.80
# Epoch   400, train loss 0.003017, train error 0.00,  test loss 3.334970, test error 50.80
# Epoch   400, train loss 0.003017, train error 0.00,  test loss 3.334970, test error 50.80
# Epoch   500, train loss 0.002172, train error 0.00,  test loss 3.469566, test error 50.75
# Epoch   500, train loss 0.002172, train error 0.00,  test loss 3.469566, test error 50.75
# Epoch   600, train loss 0.001676, train error 0.00,  test loss 3.575409, test error 50.85
# Epoch   600, train loss 0.001676, train error 0.00,  test loss 3.575409, test error 50.85
# Epoch   700, train loss 0.001354, train error 0.00,  test loss 3.663002, test error 50.90
# Epoch   700, train loss 0.001354, train error 0.00,  test loss 3.663002, test error 50.90
# Epoch   800, train loss 0.001129, train error 0.00,  test loss 3.737574, test error 50.90
# Epoch   800, train loss 0.001129, train error 0.00,  test loss 3.737574, test error 50.90
# Epoch   900, train loss 0.000965, train error 0.00,  test loss 3.803252, test error 50.97
# Epoch   900, train loss 0.000965, train error 0.00,  test loss 3.803252, test error 50.97
# Training model with 140 hidden variables
# Epoch     0, train loss 1.943274, train error 72.30,  test loss 1.869785, test error 72.15
# Training model with 140 hidden variables
# Epoch     0, train loss 1.943274, train error 72.30,  test loss 1.869785, test error 72.15
# Epoch   100, train loss 0.035651, train error 0.00,  test loss 2.166091, test error 49.03
# Epoch   100, train loss 0.035651, train error 0.00,  test loss 2.166091, test error 49.03
# Epoch   200, train loss 0.008057, train error 0.00,  test loss 2.646849, test error 49.20
# Epoch   200, train loss 0.008057, train error 0.00,  test loss 2.646849, test error 49.20
# Epoch   300, train loss 0.004150, train error 0.00,  test loss 2.875302, test error 49.10
# Epoch   300, train loss 0.004150, train error 0.00,  test loss 2.875302, test error 49.10
# Epoch   400, train loss 0.002700, train error 0.00,  test loss 3.025211, test error 49.33
# Epoch   400, train loss 0.002700, train error 0.00,  test loss 3.025211, test error 49.33
# Epoch   500, train loss 0.001964, train error 0.00,  test loss 3.137921, test error 49.40
# Epoch   500, train loss 0.001964, train error 0.00,  test loss 3.137921, test error 49.40
# Epoch   600, train loss 0.001527, train error 0.00,  test loss 3.225273, test error 49.42
# Epoch   600, train loss 0.001527, train error 0.00,  test loss 3.225273, test error 49.42
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.299535, test error 49.50
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.299535, test error 49.50
# Epoch   800, train loss 0.001038, train error 0.00,  test loss 3.361737, test error 49.60
# Epoch   800, train loss 0.001038, train error 0.00,  test loss 3.361737, test error 49.60
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.416751, test error 49.65
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.416751, test error 49.65
# Training model with 160 hidden variables
# Epoch     0, train loss 1.947954, train error 72.28,  test loss 1.877398, test error 72.68
# Training model with 160 hidden variables
# Epoch     0, train loss 1.947954, train error 72.28,  test loss 1.877398, test error 72.68
# Epoch   100, train loss 0.028672, train error 0.00,  test loss 2.114568, test error 48.80
# Epoch   100, train loss 0.028672, train error 0.00,  test loss 2.114568, test error 48.80
# Epoch   200, train loss 0.007224, train error 0.00,  test loss 2.526139, test error 49.38
# Epoch   200, train loss 0.007224, train error 0.00,  test loss 2.526139, test error 49.38
# Epoch   300, train loss 0.003801, train error 0.00,  test loss 2.728647, test error 49.53
# Epoch   300, train loss 0.003801, train error 0.00,  test loss 2.728647, test error 49.53
# Epoch   400, train loss 0.002495, train error 0.00,  test loss 2.863200, test error 49.53
# Epoch   400, train loss 0.002495, train error 0.00,  test loss 2.863200, test error 49.53
# Epoch   500, train loss 0.001828, train error 0.00,  test loss 2.961717, test error 49.50
# Epoch   500, train loss 0.001828, train error 0.00,  test loss 2.961717, test error 49.50
# Epoch   600, train loss 0.001427, train error 0.00,  test loss 3.041446, test error 49.45
# Epoch   600, train loss 0.001427, train error 0.00,  test loss 3.041446, test error 49.45
# Epoch   700, train loss 0.001162, train error 0.00,  test loss 3.107490, test error 49.53
# Epoch   700, train loss 0.001162, train error 0.00,  test loss 3.107490, test error 49.53
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.163418, test error 49.53
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.163418, test error 49.53
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.213019, test error 49.53
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.213019, test error 49.53
# Training model with 180 hidden variables
# Epoch     0, train loss 1.925437, train error 71.20,  test loss 1.830030, test error 71.07
# Training model with 180 hidden variables
# Epoch     0, train loss 1.925437, train error 71.20,  test loss 1.830030, test error 71.07
# Epoch   100, train loss 0.024057, train error 0.00,  test loss 2.134406, test error 49.15
# Epoch   100, train loss 0.024057, train error 0.00,  test loss 2.134406, test error 49.15
# Epoch   200, train loss 0.006552, train error 0.00,  test loss 2.491854, test error 49.00
# Epoch   200, train loss 0.006552, train error 0.00,  test loss 2.491854, test error 49.00
# Epoch   300, train loss 0.003513, train error 0.00,  test loss 2.677523, test error 49.25
# Epoch   300, train loss 0.003513, train error 0.00,  test loss 2.677523, test error 49.25
# Epoch   400, train loss 0.002328, train error 0.00,  test loss 2.799723, test error 49.22
# Epoch   400, train loss 0.002328, train error 0.00,  test loss 2.799723, test error 49.22
# Epoch   500, train loss 0.001713, train error 0.00,  test loss 2.893139, test error 49.38
# Epoch   500, train loss 0.001713, train error 0.00,  test loss 2.893139, test error 49.38
# Epoch   600, train loss 0.001342, train error 0.00,  test loss 2.967671, test error 49.50
# Epoch   600, train loss 0.001342, train error 0.00,  test loss 2.967671, test error 49.50
# Epoch   700, train loss 0.001096, train error 0.00,  test loss 3.028780, test error 49.50
# Epoch   700, train loss 0.001096, train error 0.00,  test loss 3.028780, test error 49.50
# Epoch   800, train loss 0.000922, train error 0.00,  test loss 3.081563, test error 49.47
# Epoch   800, train loss 0.000922, train error 0.00,  test loss 3.081563, test error 49.47
# Epoch   900, train loss 0.000792, train error 0.00,  test loss 3.127719, test error 49.58
# Epoch   900, train loss 0.000792, train error 0.00,  test loss 3.127719, test error 49.58
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926264, train error 70.25,  test loss 1.851307, test error 71.00
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926264, train error 70.25,  test loss 1.851307, test error 71.00
# Epoch   100, train loss 0.021734, train error 0.00,  test loss 2.019580, test error 48.80
# Epoch   100, train loss 0.021734, train error 0.00,  test loss 2.019580, test error 48.80
# Epoch   200, train loss 0.006196, train error 0.00,  test loss 2.340219, test error 48.83
# Epoch   200, train loss 0.006196, train error 0.00,  test loss 2.340219, test error 48.83
# Epoch   300, train loss 0.003359, train error 0.00,  test loss 2.501931, test error 48.67
# Epoch   300, train loss 0.003359, train error 0.00,  test loss 2.501931, test error 48.67
# Epoch   400, train loss 0.002242, train error 0.00,  test loss 2.613533, test error 48.72
# Epoch   400, train loss 0.002242, train error 0.00,  test loss 2.613533, test error 48.72
# Epoch   500, train loss 0.001656, train error 0.00,  test loss 2.697032, test error 48.70
# Epoch   500, train loss 0.001656, train error 0.00,  test loss 2.697032, test error 48.70
# Epoch   600, train loss 0.001300, train error 0.00,  test loss 2.763765, test error 48.85
# Epoch   600, train loss 0.001300, train error 0.00,  test loss 2.763765, test error 48.85
# Epoch   700, train loss 0.001064, train error 0.00,  test loss 2.820194, test error 48.80
# Epoch   700, train loss 0.001064, train error 0.00,  test loss 2.820194, test error 48.80
# Epoch   800, train loss 0.000896, train error 0.00,  test loss 2.867856, test error 48.78
# Epoch   800, train loss 0.000896, train error 0.00,  test loss 2.867856, test error 48.78
# Epoch   900, train loss 0.000771, train error 0.00,  test loss 2.909622, test error 48.75
# Epoch   900, train loss 0.000771, train error 0.00,  test loss 2.909622, test error 48.75
# Training model with 250 hidden variables
# Epoch     0, train loss 1.897894, train error 69.40,  test loss 1.813605, test error 71.45
# Training model with 250 hidden variables
# Epoch     0, train loss 1.897894, train error 69.40,  test loss 1.813605, test error 71.45
# Epoch   100, train loss 0.016884, train error 0.00,  test loss 1.850402, test error 46.00
# Epoch   100, train loss 0.016884, train error 0.00,  test loss 1.850402, test error 46.00
# Epoch   200, train loss 0.005350, train error 0.00,  test loss 2.091994, test error 45.97
# Epoch   200, train loss 0.005350, train error 0.00,  test loss 2.091994, test error 45.97
# Epoch   300, train loss 0.002985, train error 0.00,  test loss 2.223185, test error 46.00
# Epoch   300, train loss 0.002985, train error 0.00,  test loss 2.223185, test error 46.00
# Epoch   400, train loss 0.002017, train error 0.00,  test loss 2.311555, test error 45.88
# Epoch   400, train loss 0.002017, train error 0.00,  test loss 2.311555, test error 45.88
# Epoch   500, train loss 0.001501, train error 0.00,  test loss 2.378305, test error 45.92
# Epoch   500, train loss 0.001501, train error 0.00,  test loss 2.378305, test error 45.92
# Epoch   600, train loss 0.001185, train error 0.00,  test loss 2.433197, test error 45.95
# Epoch   600, train loss 0.001185, train error 0.00,  test loss 2.433197, test error 45.95
# Epoch   700, train loss 0.000973, train error 0.00,  test loss 2.478323, test error 45.92
# Epoch   700, train loss 0.000973, train error 0.00,  test loss 2.478323, test error 45.92
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.517298, test error 45.92
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.517298, test error 45.92
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.551481, test error 45.97
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.551481, test error 45.97
# Training model with 300 hidden variables
# Epoch     0, train loss 1.849804, train error 67.22,  test loss 1.780465, test error 69.38
# Training model with 300 hidden variables
# Epoch     0, train loss 1.849804, train error 67.22,  test loss 1.780465, test error 69.38
# Epoch   100, train loss 0.014363, train error 0.00,  test loss 1.902050, test error 47.15
# Epoch   100, train loss 0.014363, train error 0.00,  test loss 1.902050, test error 47.15
# Epoch   200, train loss 0.004822, train error 0.00,  test loss 2.128366, test error 47.08
# Epoch   200, train loss 0.004822, train error 0.00,  test loss 2.128366, test error 47.08
# Epoch   300, train loss 0.002737, train error 0.00,  test loss 2.251780, test error 47.08
# Epoch   300, train loss 0.002737, train error 0.00,  test loss 2.251780, test error 47.08
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.335542, test error 46.90
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.335542, test error 46.90
# Epoch   500, train loss 0.001396, train error 0.00,  test loss 2.400851, test error 46.92
# Epoch   500, train loss 0.001396, train error 0.00,  test loss 2.400851, test error 46.92
# Epoch   600, train loss 0.001106, train error 0.00,  test loss 2.452691, test error 46.78
# Epoch   600, train loss 0.001106, train error 0.00,  test loss 2.452691, test error 46.78
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.496453, test error 46.83
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.496453, test error 46.83
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.534334, test error 46.78
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.534334, test error 46.78
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.567481, test error 46.72
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.567481, test error 46.72
# Training model with 400 hidden variables
# Epoch     0, train loss 1.832144, train error 64.50,  test loss 1.763910, test error 68.72
# Training model with 400 hidden variables
# Epoch     0, train loss 1.832144, train error 64.50,  test loss 1.763910, test error 68.72
# Epoch   100, train loss 0.011533, train error 0.00,  test loss 1.764443, test error 46.33
# Epoch   100, train loss 0.011533, train error 0.00,  test loss 1.764443, test error 46.33
# Epoch   200, train loss 0.004113, train error 0.00,  test loss 1.939055, test error 45.97
# Epoch   200, train loss 0.004113, train error 0.00,  test loss 1.939055, test error 45.97
# Epoch   300, train loss 0.002386, train error 0.00,  test loss 2.039540, test error 46.10
# Epoch   300, train loss 0.002386, train error 0.00,  test loss 2.039540, test error 46.10
# Epoch   400, train loss 0.001645, train error 0.00,  test loss 2.108739, test error 45.92
# Epoch   400, train loss 0.001645, train error 0.00,  test loss 2.108739, test error 45.92
# Epoch   500, train loss 0.001241, train error 0.00,  test loss 2.161078, test error 45.85
# Epoch   500, train loss 0.001241, train error 0.00,  test loss 2.161078, test error 45.85
# Epoch   600, train loss 0.000988, train error 0.00,  test loss 2.204607, test error 45.85
# Epoch   600, train loss 0.000988, train error 0.00,  test loss 2.204607, test error 45.85
# Epoch   700, train loss 0.000817, train error 0.00,  test loss 2.240710, test error 45.85
# Epoch   700, train loss 0.000817, train error 0.00,  test loss 2.240710, test error 45.85
# Epoch   800, train loss 0.000694, train error 0.00,  test loss 2.271758, test error 45.85
# Epoch   800, train loss 0.000694, train error 0.00,  test loss 2.271758, test error 45.85
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.299687, test error 45.85
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.299687, test error 45.85

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\danie\appdata\local\temp\pip-req-build-yuu9d4dg
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (3.10.7)
# Requirement already satisfied: scipy in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\danie\appdata\roaming\python\python313\site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\danie\appdata\roaming\python\python313\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\danie\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danie\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml): started
#   Building wheel for mnist1d (pyproject.toml): finished with status 'done'
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14759 sha256=9225e9aa4350cfcc3431de6ac38ddf393988d4e545121fe0d4c90c76bac9011f
#   Stored in directory: C:\Users\danie\AppData\Local\Temp\pip-ephem-wheel-cache-rzske9t3\wheels\33\99\c5\794fea38f039adfbca82fd56e4a00b3e1e4533a808baee9910
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\danie\AppData\Local\Temp\pip-req-build-yuu9d4dg'
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# *DONE
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, torch.nn.Linear):
    torch.nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.616049, train error 63.10,  test loss 1.693647, test error 69.10
# Epoch     1, train loss 1.366494, train error 49.75,  test loss 1.478019, test error 59.00
# Epoch     2, train loss 1.189683, train error 43.38,  test loss 1.387456, test error 53.00
# Epoch     3, train loss 1.032037, train error 36.70,  test loss 1.272408, test error 49.90
# Epoch     2, train loss 1.189683, train error 43.38,  test loss 1.387456, test error 53.00
# Epoch     3, train loss 1.032037, train error 36.70,  test loss 1.272408, test error 49.90
# Epoch     4, train loss 0.930823, train error 33.80,  test loss 1.238287, test error 47.90
# Epoch     5, train loss 0.829490, train error 29.22,  test loss 1.139300, test error 43.40
# Epoch     4, train loss 0.930823, train error 33.80,  test loss 1.238287, test error 47.90
# Epoch     5, train loss 0.829490, train error 29.22,  test loss 1.139300, test error 43.40
# Epoch     6, train loss 0.730747, train error 25.30,  test loss 1.119172, test error 42.60
# Epoch     7, train loss 0.641711, train error 22.38,  test loss 1.079021, test error 39.30
# Epoch     6, train loss 0.730747, train error 25.30,  test loss 1.119172, test error 42.60
# Epoch     7, train loss 0.641711, train error 22.38,  test loss 1.079021, test error 39.30
# Epoch     8, train loss 0.613183, train error 21.12,  test loss 1.114142, test error 41.60
# Epoch     8, train loss 0.613183, train error 21.12,  test loss 1.114142, test error 41.60
# Epoch     9, train loss 0.532631, train error 18.32,  test loss 1.068460, test error 38.00
# Epoch    10, train loss 0.444509, train error 13.65,  test loss 1.030987, test error 38.50
# Epoch     9, train loss 0.532631, train error 18.32,  test loss 1.068460, test error 38.00
# Epoch    10, train loss 0.444509, train error 13.65,  test loss 1.030987, test error 38.50
# Epoch    11, train loss 0.388310, train error 10.20,  test loss 1.009072, test error 37.70
# Epoch    12, train loss 0.355505, train error 9.50,  test loss 0.995432, test error 36.70
# Epoch    11, train loss 0.388310, train error 10.20,  test loss 1.009072, test error 37.70
# Epoch    12, train loss 0.355505, train error 9.50,  test loss 0.995432, test error 36.70
# Epoch    13, train loss 0.328064, train error 8.72,  test loss 1.025423, test error 36.60
# Epoch    14, train loss 0.316230, train error 8.60,  test loss 1.038109, test error 36.70
# Epoch    13, train loss 0.328064, train error 8.72,  test loss 1.025423, test error 36.60
# Epoch    14, train loss 0.316230, train error 8.60,  test loss 1.038109, test error 36.70
# Epoch    15, train loss 0.286435, train error 7.18,  test loss 1.033669, test error 36.30
# Epoch    16, train loss 0.250503, train error 5.90,  test loss 1.050513, test error 36.40
# Epoch    15, train loss 0.286435, train error 7.18,  test loss 1.033669, test error 36.30
# Epoch    16, train loss 0.250503, train error 5.90,  test loss 1.050513, test error 36.40
# Epoch    17, train loss 0.233822, train error 5.20,  test loss 1.047414, test error 36.00
# Epoch    18, train loss 0.207658, train error 3.97,  test loss 1.060793, test error 35.10
# Epoch    17, train loss 0.233822, train error 5.20,  test loss 1.047414, test error 36.00
# Epoch    18, train loss 0.207658, train error 3.97,  test loss 1.060793, test error 35.10
# Epoch    19, train loss 0.184822, train error 2.88,  test loss 1.073767, test error 36.20
# Epoch    20, train loss 0.164098, train error 2.18,  test loss 1.093667, test error 35.50
# Epoch    19, train loss 0.184822, train error 2.88,  test loss 1.073767, test error 36.20
# Epoch    20, train loss 0.164098, train error 2.18,  test loss 1.093667, test error 35.50
# Epoch    21, train loss 0.156327, train error 1.95,  test loss 1.094951, test error 35.70
# Epoch    22, train loss 0.148410, train error 1.68,  test loss 1.107988, test error 35.10
# Epoch    21, train loss 0.156327, train error 1.95,  test loss 1.094951, test error 35.70
# Epoch    22, train loss 0.148410, train error 1.68,  test loss 1.107988, test error 35.10
# Epoch    23, train loss 0.138047, train error 1.30,  test loss 1.113425, test error 35.70
# Epoch    24, train loss 0.134508, train error 1.22,  test loss 1.117151, test error 35.10
# Epoch    23, train loss 0.138047, train error 1.30,  test loss 1.113425, test error 35.70
# Epoch    24, train loss 0.134508, train error 1.22,  test loss 1.117151, test error 35.10
# Epoch    25, train loss 0.126290, train error 1.05,  test loss 1.134925, test error 36.30
# Epoch    26, train loss 0.120237, train error 0.82,  test loss 1.139921, test error 35.80
# Epoch    25, train loss 0.126290, train error 1.05,  test loss 1.134925, test error 36.30
# Epoch    26, train loss 0.120237, train error 0.82,  test loss 1.139921, test error 35.80
# Epoch    27, train loss 0.113468, train error 0.80,  test loss 1.142125, test error 35.30
# Epoch    28, train loss 0.108169, train error 0.60,  test loss 1.163014, test error 35.50
# Epoch    27, train loss 0.113468, train error 0.80,  test loss 1.142125, test error 35.30
# Epoch    28, train loss 0.108169, train error 0.60,  test loss 1.163014, test error 35.50
# Epoch    29, train loss 0.106094, train error 0.60,  test loss 1.185239, test error 36.10
# Epoch    30, train loss 0.098265, train error 0.50,  test loss 1.174090, test error 36.00
# Epoch    29, train loss 0.106094, train error 0.60,  test loss 1.185239, test error 36.10
# Epoch    30, train loss 0.098265, train error 0.50,  test loss 1.174090, test error 36.00
# Epoch    31, train loss 0.094731, train error 0.30,  test loss 1.181155, test error 35.40
# Epoch    32, train loss 0.092816, train error 0.35,  test loss 1.181633, test error 35.30
# Epoch    31, train loss 0.094731, train error 0.30,  test loss 1.181155, test error 35.40
# Epoch    32, train loss 0.092816, train error 0.35,  test loss 1.181633, test error 35.30
# Epoch    33, train loss 0.089931, train error 0.28,  test loss 1.188533, test error 35.30
# Epoch    34, train loss 0.088205, train error 0.20,  test loss 1.193647, test error 35.10
# Epoch    33, train loss 0.089931, train error 0.28,  test loss 1.188533, test error 35.30
# Epoch    34, train loss 0.088205, train error 0.20,  test loss 1.193647, test error 35.10
# Epoch    35, train loss 0.085833, train error 0.22,  test loss 1.199545, test error 35.30
# Epoch    36, train loss 0.084559, train error 0.20,  test loss 1.205265, test error 35.20
# Epoch    35, train loss 0.085833, train error 0.22,  test loss 1.199545, test error 35.30
# Epoch    36, train loss 0.084559, train error 0.20,  test loss 1.205265, test error 35.20
# Epoch    37, train loss 0.081986, train error 0.18,  test loss 1.206163, test error 35.50
# Epoch    38, train loss 0.080330, train error 0.20,  test loss 1.214532, test error 35.20
# Epoch    37, train loss 0.081986, train error 0.18,  test loss 1.206163, test error 35.50
# Epoch    38, train loss 0.080330, train error 0.20,  test loss 1.214532, test error 35.20
# Epoch    39, train loss 0.078267, train error 0.18,  test loss 1.213804, test error 35.60
# Epoch    40, train loss 0.077074, train error 0.12,  test loss 1.218638, test error 35.50
# Epoch    39, train loss 0.078267, train error 0.18,  test loss 1.213804, test error 35.60
# Epoch    40, train loss 0.077074, train error 0.12,  test loss 1.218638, test error 35.50
# Epoch    41, train loss 0.076204, train error 0.12,  test loss 1.219701, test error 35.30
# Epoch    42, train loss 0.075344, train error 0.12,  test loss 1.221944, test error 35.40
# Epoch    41, train loss 0.076204, train error 0.12,  test loss 1.219701, test error 35.30
# Epoch    42, train loss 0.075344, train error 0.12,  test loss 1.221944, test error 35.40
# Epoch    43, train loss 0.074624, train error 0.10,  test loss 1.227486, test error 35.30
# Epoch    44, train loss 0.073715, train error 0.10,  test loss 1.228606, test error 35.30
# Epoch    43, train loss 0.074624, train error 0.10,  test loss 1.227486, test error 35.30
# Epoch    44, train loss 0.073715, train error 0.10,  test loss 1.228606, test error 35.30
# Epoch    45, train loss 0.072793, train error 0.10,  test loss 1.230907, test error 35.30
# Epoch    46, train loss 0.072041, train error 0.10,  test loss 1.233564, test error 35.40
# Epoch    45, train loss 0.072793, train error 0.10,  test loss 1.230907, test error 35.30
# Epoch    46, train loss 0.072041, train error 0.10,  test loss 1.233564, test error 35.40
# Epoch    47, train loss 0.071329, train error 0.10,  test loss 1.237532, test error 35.00
# Epoch    48, train loss 0.070541, train error 0.10,  test loss 1.239361, test error 35.50
# Epoch    47, train loss 0.071329, train error 0.10,  test loss 1.237532, test error 35.00
# Epoch    48, train loss 0.070541, train error 0.10,  test loss 1.239361, test error 35.50
# Epoch    49, train loss 0.069781, train error 0.10,  test loss 1.238226, test error 35.20
# Epoch    49, train loss 0.069781, train error 0.10,  test loss 1.238226, test error 35.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
#
# - No its not a good idea to optimize hyperparametesr in this way. When you constantly test different hyperparamenters on the test set, you end up "training" on the test data
# - The test set is meant ot be held out and only used once for final evaluation
# - By optimizing based on test performance, you are overfitting to the test set
# - The final test error will be biased and won't reflect true generalization performnce
